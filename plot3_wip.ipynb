# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv(r'C:\Users\katec\Thinkful\chap_4_assignment\data\Directory_Of_Homeless_Population_By_Year.csv')

# %%
df.Year.unique()
# Out:
# array([2009, 2010, 2011, 2012], dtype=int64)

# %%
df['order'] = df['Year'].map({2009: 0, 2010: 1, 2011: 2, 2012: 3})

# %%
df.sort_values('Year', ascending = True, inplace= True)

# %%
df.sort_values(by = ['Area', 'Year'], ascending = True, inplace= True)

# %%
df.head(15)
# Out:
#     Year                       Area  Homeless Estimates  order
# 26  2009                   Subways                  968      0
# 23  2010                   Subways                 1077      1
# 14  2011                   Subways                 1275      2
# 2   2012                   Subways                 1634      3
# 31  2009      Surface Area - Bronx                  164      0
# 18  2010      Surface Area - Bronx                  174      1
# 9   2011      Surface Area - Bronx                  115      2
# 7   2012      Surface Area - Bronx                  169      3
# 30  2009   Surface Area - Brooklyn                  200      0
# 19  2010   Surface Area - Brooklyn                  428      1
# 10  2011   Surface Area - Brooklyn                  242      2
# 6   2012   Surface Area - Brooklyn                  368      3
# 24  2009  Surface Area - Manhattan                  777      0
# 17  2010  Surface Area - Manhattan                 1145      1
# ...

# %% [markdown]
# Plot 3: New York City Homeless Population by Borough by Year (8 plots)

# %% [markdown]
# first attempt: entire df - unaable to distinguish individual subplots; xticks are only correct on last subplot

# %%
fig = plt.figure()
df.groupby('Area').plot(kind= 'line', x = 'Year',y = 'Homeless Estimates', legend = None)
plt.xticks([2009,2010,2011,2012])
plt.ylabel= 'Area'
plt.title('New York City Homeless Population by Borough')

plt.show()

# %% [markdown]
# second attempt: entire df - unaable to distinguish individual subplots but xticks are correct

# %%
df.groupby('Area').plot(kind= 'line', x = 'Year',y = 'Homeless Estimates', title= "New York City Homeless Population by Borough",legend=None, subplots=True, layout=(2,2))
plt.title = area

# %% [markdown]
# third attempt: working with entire df - can identify individual areas, but looks terrible; need to fix spacing & xticks

# %%
fig, axes = plt.subplots(4,2, figsize=(15,5))
for (area, group), ax in zip(df.groupby('Area'), axes.flatten()):
    group.plot(x='Year', y='Homeless Estimates', kind='line', legend=None, ax=ax, xticks =([2009,2010,2011,2012]),title= area)

# %% [markdown]
# Plot 3 Trends:
#     > The homeless population in the Subways indicates a consistent upward trend over a 4-year period.
#     > The incidence of homeless in the Subways is most interesting, as it is much less visible to a casual observer.
#     > The trend appears to show a decrease for each area in year 2011, except for the Subways.
#     > Both Staten Island and Queens show a consistent downward trend in the homeless population after 2010.
#     > Bronx, Brooklyn, and Manhattan, as well as the Surface Total show an increase after the 2011 dip, but the 2012
#       results reflect an overall decrease in the homeless population over the 4-year period.
#     > Only the Subways and the Total Unsheltered Individuals plots show an overall increase over the 4-year period.
#       It is possible that the areas which show on overall decrease in homeless population, including the Surface
#       Total, may reflect a transfer of the homeless to the Subways rather than an actual decrease in the overall
#       indicence of homelessness in NYC.

# %% [markdown]
# slice df by area

# %%
df.Area.unique()
# Out:
# array(['Subways ', 'Surface Area - Bronx ', 'Surface Area - Brooklyn ',
#        'Surface Area - Manhattan ', 'Surface Area - Queens ',
#        'Surface Area - Staten Island ', 'Surface Total ',
#        'Total Unsheltered Individuals '], dtype=object)

# %%
df_sub = df[df['Area'] == 'Subways ']
df_brx = df[df['Area'] == 'Surface Area - Bronx ']
df_brk = df[df['Area'] == 'Surface Area - Brooklyn ']
df_man = df[df['Area'] == 'Surface Area - Manhattan ']
df_qns = df[df['Area'] == 'Surface Area - Queens ']
df_sti = df[df['Area'] == 'Surface Area - Staten Island ']
df_surt = df[df['Area'] == 'Surface Total ']
df_tot = df[df['Area'] == 'Total Unsheltered Individuals ']

# %%
df_sub.head()
# Out:
#     Year      Area  Homeless Estimates  order
# 26  2009  Subways                  968      0
# 23  2010  Subways                 1077      1
# 14  2011  Subways                 1275      2
# 2   2012  Subways                 1634      3

# %%
fig = plt.figure()
df_sub.plot(kind = 'line', x = 'Year',y = 'Homeless Estimates', title = 'New York City Homeless Population: Subway', legend = None)
plt.xticks([2009,2010,2011,2012])

plt.show()

# %% [markdown]
# Plot 3 Trends:
#     > The homeless population in the Subways indicates a consistent upward trend over a 4-year period.
#     > The incidence of homeless in the Subways is most interesting, as it is much less visible to a casual observer.

# %%
fig = plt.figure()
df_brx.plot(kind = 'line', x = 'Year',y = 'Homeless Estimates', title = 'New York City Homeless Population: Bronx', legend = None)
plt.xticks([2009,2010,2011,2012])

plt.show()

# %% [markdown]
# Plot 3 Trends:
#     > The trend shows a significant decrease in 2011.
#     > Although there is a sharp trend upward in 2012, the plot reflects an overall (small) decrease in the homeless
#     population over the 4-year period.
#     > The significant 2011 decrease requires further investigation.

# %%
fig = plt.figure()
df_brk.plot(kind = 'line', x = 'Year',y = 'Homeless Estimates', title = 'New York City Homeless Population: Brooklyn', legend = None)
plt.xticks([2009,2010,2011,2012])

plt.show()

# %% [markdown]
# Plot 3 Trends:
#     > The trend shows a significant decrease in 2011.
#     > Although there is a sharp trend upward in 2012, the plot reflects an overall (small) decrease in the homeless
#     population over the 4-year period.
#     > The significant 2011 decrease requires further investigation.

# %%
fig = plt.figure()
df_man.plot(kind = 'line', x = 'Year',y = 'Homeless Estimates', title = 'New York City Homeless Population: Manhattan', legend = None)
plt.xticks([2009,2010,2011,2012])

plt.show()

# %% [markdown]
# Plot 3 Trends:
#     > The trend shows a significant decrease in 2011.
#     > Although there is a sharp trend upward in 2012, the plot reflects a relatively large overall decrease in the
#     homeless population over the 4-year period.
#     > The significant 2011 decrease requires further investigation, as does the overall decrease.

# %%
fig = plt.figure()
df_qns.plot(kind = 'line', x = 'Year',y = 'Homeless Estimates', title = 'New York City Homeless Population: Queens', legend = None)
plt.xticks([2009,2010,2011,2012])

plt.show()

# %% [markdown]
# Plot 3 Trends:
#     > Unlike most of the other boroughs, Queens show a consistent downward trend in the homeless population after
#       2010.
#     > The consistent decrease in the homeless population over a two-year period is worthy of further investigation.

# %%
fig = plt.figure()
df_sti.plot(kind = 'line', x = 'Year',y = 'Homeless Estimates', title = 'New York City Homeless Population: Staten Island', legend = None)
plt.xticks([2009,2010,2011,2012])

plt.show()

# %% [markdown]
# Plot 3 Trends:
#     > Unlike most of the other boroughs, Staten Island show a consistent downward trend in the homeless population
#     after 2010.
#     > The consistent decrease in the homeless population over a two-year period is worthy of further investigation.

# %%
fig = plt.figure()
df_surt.plot(kind = 'line', x = 'Year',y = 'Homeless Estimates', title = 'New York City Homeless Population: Surface Total', legend = None)
plt.xticks([2009,2010,2011,2012])

plt.show()

# %% [markdown]
# Plot 3 Trends:
#     > The trend shows a significant decrease in year 2011, followed by a less significant increase in 2012.
#     > Despite the 2012 increase, the results reflect an overall decrease in the homeless population over the
#       4-year period.
#     > The overall decrease in the Surface Area homeless population is consistent with the overall decease in
#       each of the surface areas: Bronx, Brooklyn, Manhattan, Staten Island, and Queens.

# %%
fig = plt.figure()
df_tot.plot(kind = 'line', x = 'Year',y = 'Homeless Estimates', title = 'New York City Homeless Population: Total', legend = None)
plt.xticks([2009,2010,2011,2012])

plt.show()

# %% [markdown]
# Plot 3 Trends:
#     > The homeless population in the Subways indicates a consistent upward trend over a 4-year period.
#     > The incidence of homeless in the Subways is most interesting, as it is much less visible to a casual observer.
#     > The trend appears to show a decrease for each area in year 2011, except for the Subways.
#     > Both Staten Island and Queens show a consistent downward trend in the homeless population after 2010.
#     > Bronx, Brooklyn, and Manhattan, as well as the Surface Total show an increase after the 2011 dip, but the 2012
#       results reflect an overall decrease in the homeless population over the 4-year period.
#     > Only the Subways and the Total Unsheltered Individuals plots show an overall increase over the 4-year period.
#       It is possible that the areas which show on overall decrease in homeless population, including the Surface
#       Total, may reflect a transfer of the homeless to the Subways rather than an actual decrease in the overall
#       indicence of homelessness in NYC.
