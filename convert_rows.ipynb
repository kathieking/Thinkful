# %%
import pandas as pd
import numpy as np

# %%
nan = np.nan

data = {'HCAHPS Measure ID': ['H_COMP_6_LINEAR_SCORE', 'H_COMP_6_STAR_RATING',
'H_COMP_7_LINEAR_SCORE', 'H_COMP_7_STAR_RATING',
'H_HSP_RATING_LINEAR_SCORE', 'H_HSP_RATING_STAR_RATING',
'H_STAR_RATING'], 
        'Patient Survey Star Rating': [nan, 2, nan, 3, nan, 1, nan], 
        'HCAHPS Linear Mean Value': [87, nan, 90, nan, 76, nan, 71]}
df = pd.DataFrame.from_dict(data, orient='columns')

# %%
df
# Out:
#            HCAHPS Measure ID  Patient Survey Star Rating  \
# 0      H_COMP_6_LINEAR_SCORE                         NaN
# 1       H_COMP_6_STAR_RATING                         2.0
# 2      H_COMP_7_LINEAR_SCORE                         NaN
# 3       H_COMP_7_STAR_RATING                         3.0
# 4  H_HSP_RATING_LINEAR_SCORE                         NaN
# 5   H_HSP_RATING_STAR_RATING                         1.0
# 6              H_STAR_RATING                         NaN
#
#    HCAHPS Linear Mean Value
# 0                      87.0
# 1                       NaN
# 2                      90.0
# 3                       NaN
# 4                      76.0
# 5                       NaN
# 6                      71.0

# %%
df = pd.concat([df, pd.DataFrame(columns = ['discharge_LINEAR_SCORE', 'discharge_STAR_RATING',
'transition_LINEAR_SCORE', 'transition_STAR_RATING',
'Overall_LINEAR_SCORE', 'Overall_STAR_RATING',
'Summary_STAR_RATING'])], sort=False)

# %%
df
# Out:
#            HCAHPS Measure ID  Patient Survey Star Rating  \
# 0      H_COMP_6_LINEAR_SCORE                         NaN
# 1       H_COMP_6_STAR_RATING                         2.0
# 2      H_COMP_7_LINEAR_SCORE                         NaN
# 3       H_COMP_7_STAR_RATING                         3.0
# 4  H_HSP_RATING_LINEAR_SCORE                         NaN
# 5   H_HSP_RATING_STAR_RATING                         1.0
# 6              H_STAR_RATING                         NaN
#
#    HCAHPS Linear Mean Value discharge_LINEAR_SCORE dscharge_STAR_RATING  \
# 0                      87.0                    NaN                  NaN
# 1                       NaN                    NaN                  NaN
# 2                      90.0                    NaN                  NaN
# 3                       NaN                    NaN                  NaN
# 4                      76.0                    NaN                  NaN
# 5                       NaN                    NaN                  NaN
# ...

# %%
df['discharge_LINEAR_SCORE'] = df['HCAHPS Linear Mean Value'].where(df['HCAHPS Measure ID'] == 'H_COMP_6_LINEAR_SCORE')

# %%
df
# Out:
#            HCAHPS Measure ID  Patient Survey Star Rating  \
# 0      H_COMP_6_LINEAR_SCORE                         NaN
# 1       H_COMP_6_STAR_RATING                         2.0
# 2      H_COMP_7_LINEAR_SCORE                         NaN
# 3       H_COMP_7_STAR_RATING                         3.0
# 4  H_HSP_RATING_LINEAR_SCORE                         NaN
# 5   H_HSP_RATING_STAR_RATING                         1.0
# 6              H_STAR_RATING                         NaN
#
#    HCAHPS Linear Mean Value  discharge_LINEAR_SCORE dscharge_STAR_RATING  \
# 0                      87.0                    87.0                  NaN
# 1                       NaN                     NaN                  NaN
# 2                      90.0                     NaN                  NaN
# 3                       NaN                     NaN                  NaN
# 4                      76.0                     NaN                  NaN
# ...

# %%
new_linear = df[['discharge_LINEAR_SCORE', 'transition_LINEAR_SCORE', 
'Overall_LINEAR_SCORE']]

# %%
linear = [['H_COMP_6_LINEAR_SCORE', 'H_COMP_7_LINEAR_SCORE', 'H_HSP_RATING_LINEAR_SCORE']]

# %%
for column in [new_linear, linear]:
    df[new_linear] = df['HCAHPS Linear Mean Value'].where(df['HCAHPS Measure ID'] == linear)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-aa6d92439623> in <module>
#       1 for column in [new_linear, linear]:
# ----> 2     df[new_linear] = df['HCAHPS Linear Mean Value'].where(df['HCAHPS Measure ID'] == linear)
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in wrapper(self, other, axis)
#    1743             # as it will broadcast
#    1744             if other.ndim != 0 and len(self) != len(other):
# -> 1745                 raise ValueError('Lengths must match to compare')
#    1746
#    1747             res_values = na_op(self.values, np.asarray(other))
#
# ValueError: Lengths must match to compare

# %%
df
